# %% [markdown]
# <a href="https://colab.research.google.com/github/GALIDEVARA05/FMML_assignments/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 02:56:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   368MB/s    in 0.2s
#
# 2024-04-03 02:56:45 (368 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29355  1709.01841v3  We propose a new method that uses deep learnin...    cs
# 38591   1111.1093v1  Biometric security is a fast growing area. Pro...    cs
# 11795  1701.06120v1  In this paper, a genetic algorithm-based frequ...    cs
# 1463   1802.08314v1  Vanishing long-term gradients are a major issu...    cs
# 22134  1501.05200v1  We are motivated by problems that arise in a n...  stat
# ...             ...                                                ...   ...
# 33054  1801.08930v1  Meta-learning allows an intelligent agent to l...    cs
# 8742   1803.00397v1  When major disaster occurs the questions are r...    cs
# 23587   0710.0043v2  A recent paper \cite{CaeCaeSchBar06} proposed ...    cs
# 6674   1705.01708v2  Maximizing the area under the receiver operati...  stat
# 37160  1609.02316v1  This paper introduces the revival of the popul...    cs
#
#                                                    title  year  \
# 29355  An inner-loop free solution to inverse problem...  2017
# 38591  Securing Biometric Images using Reversible Wat...  2011
# 11795  Effective and Extensible Feature Extraction Me...  2017
# 1463   High Order Recurrent Neural Networks for Acous...  2018
# 22134  Minimax Optimal Sparse Signal Recovery with Po...  2015
# ...                                                  ...   ...
# 33054  Recasting Gradient-Based Meta-Learning as Hier...  2018
# 8742   Satellite imagery analysis for operational dam...  2018
# 23587  Graph rigidity, Cyclic Belief Propagation and ...  2007
# 6674   Semi-Supervised AUC Optimization based on Posi...  2017
# 37160  Ms. Pac-Man Versus Ghost Team CIG 2016 Competi...  2016
#
#                                                 keywords
# 29355  [techniques, accelerate, alternating, directio...
# 38591  [biometric, protecting, biometric, important, ...
# 11795  [algorithm, frequency, electroencephalogram, f...
# 1463   [vanishing, gradients, recurrent, alleviated, ...
# 22134  [motivated, applications, marketing, explosive...
# ...                                                  ...
# 33054  [intelligent, improving, performance, hierarch...
# 8742   [questions, authorities, humanitarian, efficie...
# 23587  [polynomial, performing, isometric, probabilis...
# 6674   [maximizing, operating, characteristic, imbala...
# 37160  [introduces, competition, observability, const...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29355    [techniques, accelerate, alternating, directio...
# 38591    [biometric, protecting, biometric, important, ...
# 11795    [algorithm, frequency, electroencephalogram, f...
# 1463     [vanishing, gradients, recurrent, alleviated, ...
# 22134    [motivated, applications, marketing, explosive...
#                                ...
# 21978    [processes, simulated, deterministic, acceptin...
# 13147    [initiates, generalization, assumption, princi...
# 7439     [significant, applications, corresponding, con...
# 17900    [identifying, inaccurate, significant, difficu...
# 28749    [submission, localization, activitynet, challe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8886 words.
# Out of those 4589 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98638b08-5720-48cc-96c1-646dcdad8589" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98638b08-5720-48cc-96c1-646dcdad8589")) {                    Plotly.newPlot(                        "98638b08-5720-48cc-96c1-646dcdad8589",                        [{"x":["techniques","alternating","multipliers","inversion","approximate","denoising","efficiency","experiments","drawbacks","inference","direction","empirical","architectures","extensive","typically","dependent","proximity","independent","convolutional","demonstrate","conventional","intractability","amortized","minimization","measurements","accelerate","regression","variables","limitations","specifically","conditional","synthetic","retrieved","alternate","attackers","different","development","rotational","expansion","measurement","reversible","effective","watermark","protecting","acceptable","biometrics","watermarking","assessment","completely","understudied","difference","watermarked","maintains","comparing","replacement","biometric","important","frequency","multilayer","epileptic","additionally","optimized","transformation","extensibility","electroencephalogram","validation","experimentally","reasonable","generated","perceptron","respectively","optimization","illustrate","discriminant","extensible","algorithm","extraction","classification","subsequently","instantaneous","extracted","nonlinear","independence","therefore","remarkable","classifiers","accuracies","selection","connections","modelling","broadcast","functions","additional","activation","recognition","recurrent","parameters","addresses","gradients","rectified","alleviated","associated","computation","vanishing","corresponding","theoretically","particular","distributed","marketing","modalities","constrained","likelihood","performance","superposition","detection","complexity","statistics","contaminated","identically","observation","fundamental","applications","motivated","fundamentally","observations","tightness","computationally","tractable","landscape","exponentially","composition","multivariate","computational","dependence","variational","correlations","distribution","satellite","correlation","dimensional","contextual","footprint","integrates","generating","advantage","sustainability","structures","information","dependency","availability","confounder","dimensions","covariance","influence","coefficients","describing","orientation","statistical","characteristic","detecting","predictor","concentration","dependences","confounding","correlated","quantitatively","assumption","eigenspaces","potential","degeneracy","heterogeneous","identifiability","resulting","simulations","estimates","estimator","graphical","technique","expectation","application","conditions","precision","estimation","maximization","penalized","parameter","consistent","reconstruction","regularity","considers","challenging","implements","grounding","comparable","framework","introducing","configuration","similarity","comprehensive","algorithms"],"y":[358,33,19,8,117,37,166,580,12,221,62,173,113,158,98,65,7,152,347,551,107,4,3,60,51,22,124,124,51,167,105,139,8,7,3,742,127,6,25,27,6,249,3,2,17,5,5,45,38,3,66,3,10,90,8,13,372,58,18,2,71,57,65,4,3,50,48,29,170,21,82,295,72,14,8,817,141,493,26,6,112,62,25,142,23,98,26,140,51,65,8,204,115,28,378,138,250,59,38,9,2,116,154,8,126,38,267,108,6,31,69,69,883,2,347,246,55,5,5,76,96,441,70,14,83,2,94,40,13,23,44,22,290,24,54,30,187,13,76,185,58,6,29,85,95,2,143,691,49,25,0,36,26,48,32,47,27,164,23,74,8,15,1,2,26,22,65,0,147,3,31,3,146,62,68,33,62,261,27,256,135,94,195,30,5,101,101,94,7,40,252,16,8,94,502,51,18,148,49,602],"type":"bar"},{"x":["techniques","alternating","multipliers","inversion","approximate","denoisin ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4589,), (4589, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Toward</span> <span style=''>better</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>a</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>Relief</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>try</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>nowadays</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>search</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relevance</span> <span style=''>measure</span> <span style=''>for</span> <span style=''>the</span> <span style=''>features</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style=''>domain</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relevance</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.34883720930232565);'>primarily</span> <span style=''>used</span> <span style=''>for</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>as</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>it</span> <span style=''>but</span> <span style=''>it</span> <span style=''>is</span> <span style=''>also</span> <span style=''>useful</span> <span style=''>to</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understand</span> <span style=''>a</span> <span style=''>problems</span> <span style=''>domain</span> <span style=''>or</span> <span style=''>to</span> <span style=''>guide</span> <span style=''>an</span> <span style=''>inductor</span> <span style=''>in</span> <span style=''>its</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>Relief</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.31746031746031755);'>effective</span> <span style=''>in</span> <span style=''>this</span> <span style=''>task</span> <span style=''>Some</span> <span style=''>other</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>reviewed</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>give</span> <span style=''>some</span> <span style=''>context</span> <span style=''>and</span> <span style=''>then</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>different</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explained</span> <span style=''>One</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Locally</span> <span style=''>Adaptive</span> <span style=''>Normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>normal</span> <span style=''>density</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ellipsoidal</span> <span style=''>shape</span> <span style=''>is</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>metric</span> <span style=''>We</span> <span style=''>suggest</span> <span style=''>to</span> <span style=''>replace</span> <span style=''>this</span> <span style=''>metric</span> <span style=''>with</span> <span style=''>a</span> <span style=''>locally</span> <span style=''>adaptive</span> <span style=''>smoothly</span> <span style=''>changing</span> <span style=''>(Riemannian)</span> <span style=''>metric</span> <span style=''>that</span> <span style=''>favors</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>high</span> <span style=''>local</span> <span style=''>density</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>locally</span> <span style=''>adaptive</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>(LAND)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>data</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>lie</span> <span style=''>near</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>manifold</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>mathbbRD</span> <span style=''>The</span> <span style=''>LAND</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>only</span> <span style=''>on</span> <span style=''>a</span> <span style=''>mean</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>and</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>under</span> <span style=''>the</span> <span style=''>given</span> <span style=''>metric</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>metric</span> <span style=''>is</span> <span style=''>however</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>Kernel</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalisations</span> <span style=''>of</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Components</span> <span style=''>Analysis</span> <span style=''>(KPCA)</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporate</span> <span style='background-color:rgba(0, 255, 0, 0.37074148296593185);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>of</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>points</span> <span style=''>The</span> <span style=''>first</span> <span style=''>MV</span> <span style=''>KPCA</span> <span style=''>penalises</span> <span style=''>within</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>variances</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>The</span> <span style=''>second</span> <span style=''>LSKPCA</span> <span style=''>is</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>of</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.49180327868852464);'>regression</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>PCA</span> <span style=''>The</span> <span style=''>final</span> <span style=''>LR</span> <span style=''>KPCA</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteratively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reweighted</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>which</span> <span style=''>achieves</span> <span style=''>a</span> <span style=''>sigmoid</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>on</span> <span style=''>the</span> <span style=''>labeled</span> <span style=''>points</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>risk</span> <span style=''>bound</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>real</span> <span style=''>and</span> <span style=''>toy</span> <span style=''>data</span> <span style=''>sets</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Detecting</span> <span style=''>Learning</span> <span style=''>vs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Memorization</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>using</span> <span style=''>Shared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Validation</span> <span style=''>Sets</span> <br/><br/><span style=''>The</span> <span style=''>roles</span> <span style=''>played</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>memorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>topic</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>research</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>this</span> <span style=''>subject</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>DNNs</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>shuffled</span> <span style=''>labels</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitatively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>from</span> <span style=''>DNNs</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>real</span> <span style=''>labels</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>memorization</span> <span style=''>from</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNNs)</span> <span style=''>trained</span> <span style=''>as</span> <span style=''>usual</span> <span style=''>(ie</span> <span style=''>using</span> <span style=''>the</span> <span style=''>real</span> <span style=''>labels</span> <span style=''>to</span> <span style=''>guide</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>shuffled</span> <span style=''>labels)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>weather</span> <span style=''>the</span> <span style=''>DNN</span> <span style=''>has</span> <span style=''>learned</span> <span style=''>andor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>memorized</span> <span style=''>happens</span> <span style=''>in</span> <span style=''>a</span> <span style=''>separate</span> <span style=''>step</span> <span style=''>where</span> <span style=''>we</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>shallow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>the</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12144886363636363)
# 	experimental (0.13352272727272727)
# 	evaluation (0.09978693181818182)
# 	information (0.24538352272727273)
# 	architecture (0.08487215909090909)
# 	segmentation (0.07883522727272728)
# 	detection (0.12322443181818182)
# 	different (0.2634943181818182)
# 	convolutional (0.12322443181818182)
# 	recognition (0.13423295454545456)
#
# Some Statistics words are:
# 	theoretical (0.14919354838709678)
# 	stochastic (0.13608870967741934)
# 	statistical (0.14868951612903225)
# 	variables (0.14112903225806453)
# 	estimation (0.18296370967741934)
# 	inference (0.19254032258064516)
# 	algorithm (0.40524193548387094)
# 	distribution (0.18901209677419356)
# 	dimensional (0.1930443548387097)
# 	regression (0.18346774193548387)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fff04729-045c-41e8-8fd1-7c853a64daab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fff04729-045c-41e8-8fd1-7c853a64daab")) {                    Plotly.newPlot(                        "fff04729-045c-41e8-8fd1-7c853a64daab",                        [{"x":["techniques","alternating","multipliers","inversion","approximate","denoising","efficiency","experiments","drawbacks","inference","direction","empirical","architectures","extensive","typically","dependent","proximity","independent","convolutional","demonstrate","conventional","intractability","amortized","minimization","measurements","accelerate","regression","variables","limitations","specifically","conditional","synthetic","retrieved","alternate","attackers","different","development","rotational","expansion","measurement","reversible","effective","watermark","protecting","acceptable","biometrics","watermarking","assessment","completely","understudied","difference","watermarked","maintains","comparing","replacement","biometric","important","frequency","multilayer","epileptic","additionally","optimized","transformation","extensibility","electroencephalogram","validation","experimentally","reasonable","generated","perceptron","respectively","optimization","illustrate","discriminant","extensible","algorithm","extraction","classification","subsequently","instantaneous","extracted","nonlinear","independence","therefore","remarkable","classifiers","accuracies","selection","connections","modelling","broadcast","functions","additional","activation","recognition","recurrent","parameters","addresses","gradients","rectified","alleviated","associated","computation","vanishing","corresponding","theoretically","particular","distributed","marketing","modalities","constrained","likelihood","performance","superposition","detection","complexity","statistics","contaminated","identically","observation","fundamental","applications","motivated","fundamentally","observations","tightness","computationally","tractable","landscape","exponentially","composition","multivariate","computational","dependence","variational","correlations","distribution","satellite","correlation","dimensional","contextual","footprint","integrates","generating","advantage","sustainability","structures","information","dependency","availability","confounder","dimensions","covariance","influence","coefficients","describing","orientation","statistical","characteristic","detecting","predictor","concentration","dependences","confounding","correlated","quantitatively","assumption","eigenspaces","potential","degeneracy","heterogeneous","identifiability","resulting","simulations","estimates","estimator","graphical","technique","expectation","application","conditions","precision","estimation","maximization","penalized","parameter","consistent","reconstruction","regularity","considers","challenging","implements","grounding","comparable","framework","introducing","configuration","similarity","comprehensive","algorithms","probabilistic","approaches","subproblems","foundations","knowledge","integrate","referenced","relational","prediction","relationships","discovery","benchmark","furthermore","following","considered","previously","magnitude","inequalities","criterion","improvement","indicating","variations","establishing","leverages","reinforcement","probability","undiscounted","interacts","transportation","structural","identification","equations","interventions","compatible","determined","conclusions","parametrization","identified","recursive","representing","represents","sufficient","predicting","combination","quantitative","qualitative","condition","prepositions","describes","translating","addressed","expressions","translate"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounder
# 	eigenspaces
# 	misclassify
# 	logarithmically
# 	parallelizes
# 	inhomogeneity
# 	looseness
# 	magnetoencephalographic
# 	borderline
# 	psychiatry
# 	actionable
# 	plentiful
# 	criterions
# 	connectome
# 	reparametrization
# 	microbial
# 	undesired
# 	indiscriminate
# 	ultrametric
# 	dendrograms
# Some words which never appear in Statistics papers:
# 	watermark
# 	biometrics
# 	watermarking
# 	understudied
# 	watermarked
# 	grounding
# 	referenced
# 	prepositions
# 	translating
# 	keypoints
# 	messaging
# 	stylometry
# 	felzenszwalb
# 	compiling
# 	fortunately
# 	propositional
# 	compilation
# 	metaheuristic
# 	replicating
# 	neuromorphic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053528352010748e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
